# %% [markdown]
# # Feynn Labs Project - 3

# %% [markdown]
# # EV Market Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('ev_dataset.xlsx')
data
# Out:
#           Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                        ID.3 Pure      10.0           160
# 2      Polestar                                2       4.7           210
# 3           BMW                              iX3       6.8           180
# 4         Honda                                e       9.5           145
# ..          ...                              ...       ...           ...
# 97       Nissan                      Ariya 63kWh       7.5           160
# 98         Audi    e-tron S Sportback 55 quattro       4.5           210
# 99       Nissan              Ariya e-4ORCE 63kWh       5.9           200
# 100      Nissan  Ariya e-4ORCE 87kWh Performance       5.1           200
# 101       Byton                M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0       460              70.0              161             940         Yes
# 1       270              45.0              167             250         Yes
# 2       400              75.0              181             620         Yes
# 3       360              74.0              206             560         Yes
# 4       170              28.5              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro          INR
# ...

# %%
data.tail()
# Out:
#       Brand                            Model  AccelSec  TopSpeed_KmH  \
# 97   Nissan                      Ariya 63kWh       7.5           160
# 98     Audi    e-tron S Sportback 55 quattro       4.5           210
# 99   Nissan              Ariya e-4ORCE 63kWh       5.9           200
# 100  Nissan  Ariya e-4ORCE 87kWh Performance       5.1           200
# 101   Byton                M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 97        330              63.0              191             440         Yes
# 98        335              86.5              258             540         Yes
# 99        325              63.0              194             440         Yes
# 100       375              87.0              232             450         Yes
# 101       400              95.0              238             480         Yes
#
#     PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro          INR
# ...

# %%
data.shape
# Out:
# (102, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             102 non-null    object
#  1   Model             102 non-null    object
#  2   AccelSec          102 non-null    float64
#  3   TopSpeed_KmH      102 non-null    int64
#  4   Range_Km          102 non-null    int64
#  5   Battery_Pack Kwh  102 non-null    float64
#  6   Efficiency_WhKm   102 non-null    int64
#  7   FastCharge_KmH    102 non-null    int64
#  8   RapidCharge       102 non-null    object
#  9   PowerTrain        102 non-null    object
#  10  PlugType          102 non-null    object
#  11  BodyStyle         102 non-null    object
#  12  Segment           102 non-null    object
#  13  Seats             102 non-null    int64
#  14  PriceEuro         102 non-null    int64
#  15  INR               102 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Brand               0
# Model               0
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# INR                 0
# dtype: int64

# %%
data.describe().T
# Out:
#                   count          mean           std          min  \
# AccelSec          102.0  7.391176e+00  3.031913e+00        2.100
# TopSpeed_KmH      102.0  1.793137e+02  4.377123e+01      123.000
# Range_Km          102.0  3.386275e+02  1.267006e+02       95.000
# Battery_Pack Kwh  102.0  6.541569e+01  2.995578e+01       16.700
# Efficiency_WhKm   102.0  1.893039e+02  2.967907e+01      104.000
# FastCharge_KmH    102.0  4.356863e+02  2.204474e+02        0.000
# Seats             102.0  4.882353e+00  7.996796e-01        2.000
# PriceEuro         102.0  5.599759e+04  3.425072e+04    20129.000
# INR               102.0  4.583352e+06  2.803391e+06  1647540.534
#
#                            25%         50%        75%         max
# AccelSec          5.100000e+00        7.30        9.0        22.4
# TopSpeed_KmH      1.500000e+02      160.00      200.0       410.0
# Range_Km          2.500000e+02      340.00      400.0       970.0
# ...

# %%
data['Brand'].unique()
# Out:
# array(['Tesla', 'Volkswagen', 'Polestar', 'BMW', 'Honda', 'Lucid',
#        'Peugeot', 'Audi', 'Mercedes', 'Nissan', 'Hyundai', 'Porsche',
#        'MG', 'Mini', 'Opel', 'Skoda', 'Volvo', 'Kia', 'Renault', 'Mazda',
#        'Lexus', 'CUPRA', 'SEAT', 'Lightyear', 'Aiways', 'DS', 'Citroen',
#        'Jaguar', 'Ford', 'Byton', 'Sono', 'Smart', 'Fiat'], dtype=object)

# %%
data['Model'].unique()
# Out:
# array(['Model 3 Long Range Dual Motor', 'ID.3 Pure', 2, 'iX3', 'e', 'Air',
#        'e-Golf', 'e-208', 'Model 3 Standard Range Plus', 'Q4 e-tron',
#        'EQC 400 4MATIC', 'Leaf', 'Kona Electric 64 kWh', 'i4',
#        'IONIQ Electric', 'ID.3 Pro S', 'Taycan Turbo S', 'e-Up!', 'ZS EV',
#        'Cooper SE', 'Corsa-e', 'Model Y Long Range Dual Motor',
#        'Enyaq iV 50', 'e-tron GT', 'Model 3 Long Range Performance',
#        'ID.4', 'ID.3 Pro', 'XC40 P8 AWD Recharge', 'i3 120 Ah',
#        'e-2008 SUV', 'e-tron 50 quattro', 'e-Niro 64 kWh',
#        'Zoe ZE50 R110', 'Cybertruck Tri Motor', 'MX-30', 'Leaf e+',
#        'UX 300e', 'el-Born', 'Zoe ZE50 R135', 'EQA', 'Model S Long Range',
#        'Kona Electric 39 kWh', 'e-tron Sportback 55 quattro',
#        'CITIGOe iV', 'Mii Electric', 'E -Soul 64 kWh', 'Ampera-e',
#        'Taycan 4S', 'One', 'U5', 'e-tron 55 quattro', 'Roadster',
#        'Mokka-e', 'Enyaq iV 80', 'Model X Long Range', 'e Advance',
# ...

# %%
data['PlugType'].unique()
# Out:
# array(['Type 2 CCS', 'Type 2 CHAdeMO', 'Type 2', 'Type 1 CHAdeMO'],
#       dtype=object)

# %%
data['PowerTrain'].unique()
# Out:
# array(['AWD', 'RWD', 'FWD'], dtype=object)

# %%
data['BodyStyle'].unique()
# Out:
# array(['Sedan', 'Hatchback', 'Liftback', 'SUV', 'Pickup', 'MPV', 'Cabrio',
#        'SPV', 'Station'], dtype=object)

# %% [markdown]
# # Data Visualization

# %%
sns.countplot(data['PowerTrain'])
plt.show()
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['RapidCharge'])
plt.show()
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (8,5))
sns.countplot(data['BodyStyle'], data = data, hue='PowerTrain')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize = (24,8))
sns.barplot(x = data['Brand'], y = data['PriceEuro'])
plt.show()

# %%
plt.figure(figsize = (9,7))
data['Segment'].value_counts().plot.pie(autopct = '%.2f%%', pctdistance=0.4)
plt.show()

# %%
plt.figure(figsize = (9,7))
data['PlugType'].value_counts().plot.pie(autopct = '%.2f%%', pctdistance=0.4)
plt.show()

# %% [markdown]
# # Data Analysis

# %%
data['Model'] = data['Model'].astype(str)

# %%
data['C_name'] = data['Brand'] + data['Model']

# %%
df_1= data.loc[data['INR'] <=4000000]
df_2 = data.loc[data['INR'] >4000000]
t1 = ['Less than INR 4000000']
t2 = ['More thanINR 4000000']

# %% [markdown]
# # Range - Battery Pack

# %%
#range-batterypack
def range_batterypack(data, text):
    fig = plt.figure(figsize=(20,5))
    a1= plt.subplot()
    a1.bar(data["C_name"], data["Range_Km"], label='Range (Km)', color='green')
    plt.legend(loc= "upper left", bbox_to_anchor=(0,1.105))
    a2 = a1.twinx()
    a2.scatter(data["C_name"], data["Battery_Pack Kwh"], label= "Battery Pack", color= 'black')
    plt.title('''RANGE(Km) vs BATTERY PACK CAPACITY (kwh) of EV's costing {}'''.format(text), fontsize=12)
    a1.set_xlabel('Models', size= 16)
    a1.set_ylabel('Range (Km)', color = 'blue')
    a2.set_ylabel('Battery Pack Capacity (Kwh)', color='black')
    plt.legend(loc='upper left', bbox_to_anchor=(0,1))
    a1.set_xticklabels(df_1['C_name'], rotation = 'vertical')
    plt.show()
    
range_batterypack(df_1, t1)
range_batterypack(df_2, t2)
# Out:
# C:\Users\MY-PC\AppData\Local\Temp/ipykernel_664/1523676411.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a1.set_xticklabels(df_1['C_name'], rotation = 'vertical')

# %% [markdown]
# # Range - Vehicle Price

# %%
#Range - Price
def range_price(data, text):
    fig = plt.figure(figsize=(20, 5))
    a1 = plt.subplot()
    a1.bar(data['C_name'], data['Range_Km'], label='Range (Km)', color='blue')
    plt.legend(loc='upper left', bbox_to_anchor = (0, 1.1))
    a2= a1.twinx()
    a2.scatter(data['C_name'], data['INR'], label = 'Price', color = 'black')
    plt.title('''RANGE (Km) vs PRICE(INR) OF EV's COSTING {}'''.format(text), fontsize=16)
    a1.set_xlabel('Models', size=16)
    a1.set_ylabel('Range (Km)', color = 'red')
    a2.set_ylabel('Price(INR)', color= 'black')
    plt.legend(loc = 'upper left', bbox_to_anchor = (0,1.1))
    a1.set_xticklabels(df_1['C_name'], rotation = 'vertical')
    plt.show()
    
range_price(df_1, t1)
range_price(df_2, t2)
# Out:
# C:\Users\MY-PC\AppData\Local\Temp/ipykernel_664/739021973.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a1.set_xticklabels(df_1['C_name'], rotation = 'vertical')

# %% [markdown]
# # Acceleration(0-100km/hr)

# %%
def acc(data, text):
    plt.figure(figsize=(20,5))
    sns.set_theme(style="darkgrid")
    sns.barplot('C_name', 'AccelSec', data=data, hue=data['PowerTrain'])
    plt.title('''Acceleration 0-100 Km of EV's costing {}'''.format(text), fontsize=16)
    plt.ylabel('Acceleration (Seconds)')
    plt.xlabel('Model')
    plt.xticks(rotation = 90)
    plt.show()
    
acc(df_1, t1)
acc(df_2, t2)
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Vehicles with Maximum Efficiency

# %%
pd.set_option('display.max_columns', None)
efficiency = data.sort_values(by = 'Efficiency_WhKm')
print(efficiency[['C_name', 'Efficiency_WhKm', 'Range_Km', 'PowerTrain', 'Battery_Pack Kwh', 'INR']])
# Out:
#                                C_name  Efficiency_WhKm  Range_Km PowerTrain  \
# 48                       LightyearOne              104       575        AWD
# 14              HyundaiIONIQ Electric              153       250        FWD
# 8    TeslaModel 3 Standard Range Plus              153       310        RWD
# 41        HyundaiKona Electric 39 kWh              154       255        FWD
# 74                           SonoSion              156       225        FWD
# ..                                ...              ...       ...        ...
# 98  Audie-tron S Sportback 55 quattro              258       335        AWD
# 67         TeslaCybertruck Dual Motor              261       460        AWD
# 33          TeslaCybertruck Tri Motor              267       750        AWD
# 90            Audie-tron S 55 quattro              270       320        AWD
# 84               MercedesEQV 300 Long              273       330        FWD
#
#     Battery_Pack Kwh           INR
# ...
